# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from skimage.transform import resize
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# Function to explore and visualize data distribution
def explore_data_distribution(data_dir, label_mapping, metadata):
    """
    Explore the dataset structure and visualize class distribution
    
    Args:
        data_dir: Directory containing the spectrograms
        label_mapping: Dictionary mapping primary_label to numerical label
        metadata: DataFrame containing metadata about classes
        
    Returns:
        DataFrame with counts of chirp files per class
    """
    chirp_count_per_class = defaultdict(int)
    file_type_counts = defaultdict(int)
    total_files = 0
    
    # Create reverse mapping for display
    label_to_class = {}
    for primary_label, label in label_mapping.items():
        class_name = metadata[metadata['primary_label'].astype(str) == primary_label]['class_name'].values
        if len(class_name) > 0:
            label_to_class[label] = class_name[0]
    
    # Count files
    for folder_name in os.listdir(data_dir):
        if folder_name in label_mapping:
            label = label_mapping[folder_name]
            class_name = label_to_class.get(label, f"Class {label}")
            folder_path = os.path.join(data_dir, folder_name)
            
            for filename in os.listdir(folder_path):
                if filename.endswith('.npy'):
                    total_files += 1
                    
                    # Track file types
                    if '_chirp.npy' in filename:
                        chirp_count_per_class[label] += 1
                        file_type_counts['chirp'] += 1
                    elif '_denoised.npy' in filename:
                        file_type_counts['denoised'] += 1
                    elif '_denoised_hpss.npy' in filename:
                        file_type_counts['denoised_hpss'] += 1
                    elif '_denoised_median_filter.npy' in filename:
                        file_type_counts['denoised_median_filter'] += 1
                    elif '_denoised_spectral.npy' in filename:
                        file_type_counts['denoised_spectral'] += 1
    
    # Convert to DataFrame for easier analysis
    chirp_df = pd.DataFrame([
        {'class_label': label, 'class_name': label_to_class.get(label, f"Class {label}"), 'chirp_count': count}
        for label, count in chirp_count_per_class.items()
    ]).sort_values(by='chirp_count', ascending=False)
    
    # Print statistics
    print("\n===== Dataset Exploration =====")
    print(f"Total number of .npy files: {total_files}")
    print("\nFile type distribution:")
    for file_type, count in file_type_counts.items():
        print(f"  {file_type}: {count} files")
    
    print("\n===== Class Distribution (chirp files) =====")
    print(f"{'Class Name':<30} | {'Count':<10}")
    print("-" * 43)
    
    for _, row in chirp_df.iterrows():
        print(f"{row['class_name']:<30} | {row['chirp_count']:<10}")
    
    # Create a bar chart of class distribution
    plt.figure(figsize=(12, 8))
    plt.bar(chirp_df['class_name'], chirp_df['chirp_count'])
    plt.xticks(rotation=90)
    plt.xlabel('Class')
    plt.ylabel('Number of Chirp Files')
    plt.title('Class Distribution - Number of Chirp Files')
    plt.tight_layout()
    plt.show()
    
    return chirp_df

# Function to create balanced train/test split
def split_balanced_train_test(data_dir, label_mapping, metadata, target_shape=(128, 64), test_ratio=0.2):
    """
    Create a balanced train/test split for chirp files
    
    Args:
        data_dir: Directory containing the spectrograms
        label_mapping: Dictionary mapping primary_label to numerical label
        metadata: DataFrame containing metadata about classes
        target_shape: Target shape for resized spectrograms
        test_ratio: Proportion of data to use for testing
        
    Returns:
        X_train, y_train, train_files, X_test, y_test, test_files
    """
    # Step 1: Gather all chirp file paths by class label
    class_files = defaultdict(list)

    for folder_name in os.listdir(data_dir):
        if folder_name in label_mapping:
            label = label_mapping[folder_name]
            folder_path = os.path.join(data_dir, folder_name)
            for filename in os.listdir(folder_path):
                if '_chirp.npy' in filename:
                    file_path = os.path.join(folder_path, filename)
                    class_files[label].append(file_path)

    # Step 2: Determine minimum class count (for balancing)
    min_class_count = min(len(files) for files in class_files.values())
    
    # Create a mapping from numerical label to class name
    label_to_class = {}
    for primary_label, label in label_mapping.items():
        class_name = metadata[metadata['primary_label'].astype(str) == primary_label]['class_name'].values
        if len(class_name) > 0:
            label_to_class[label] = class_name[0]
    
    # Step 3: Balance classes by taking the same number from each
    train_data, train_labels, train_files = [], [], []
    test_data, test_labels, test_files = [], [], []
    
    # For tracking distribution
    train_counts = defaultdict(int)
    test_counts = defaultdict(int)

    for label, files in class_files.items():
        # Sort for reproducibility
        files = sorted(files)
        
        # Only keep min_class_count files
        selected_files = files[:min_class_count]
        
        # Split into train and test
        class_train_files, class_test_files = train_test_split(
            selected_files, test_size=test_ratio, random_state=42
        )
        
        # Load training samples
        for file_path in class_train_files:
            spectrogram = np.load(file_path)
            spectrogram = resize(spectrogram, target_shape, mode='reflect', anti_aliasing=True)
            spectrogram = np.expand_dims(spectrogram, axis=-1)  # Add channel dimension
            train_data.append(spectrogram)
            train_labels.append(label)
            train_files.append(file_path)
            train_counts[label] += 1

        # Load testing samples
        for file_path in class_test_files:
            spectrogram = np.load(file_path)
            spectrogram = resize(spectrogram, target_shape, mode='reflect', anti_aliasing=True)
            spectrogram = np.expand_dims(spectrogram, axis=-1)  # Add channel dimension
            test_data.append(spectrogram)
            test_labels.append(label)
            test_files.append(file_path)
            test_counts[label] += 1

    # Print distribution analysis
    print("\n===== Class Distribution After Balanced Split =====")
    print(f"{'Class Name':<30} | {'Training Count':<15} | {'Test Count':<15} | {'Total':<15}")
    print("-" * 80)
    
    total_train = 0
    total_test = 0
    
    # Print counts for each class
    for label in sorted(set(train_counts.keys()) | set(test_counts.keys())):
        class_name = label_to_class.get(label, f"Class {label}")
        train_count = train_counts[label]
        test_count = test_counts[label]
        total = train_count + test_count
        
        print(f"{class_name[:30]:<30} | {train_count:<15} | {test_count:<15} | {total:<15}")
        total_train += train_count
        total_test += test_count
    
    print("-" * 80)
    print(f"{'Total':<30} | {total_train:<15} | {total_test:<15} | {total_train + total_test:<15}")
    
    # Plot the distribution
    plt.figure(figsize=(12, 8))
    
    x = np.arange(len(label_to_class))
    width = 0.35
    
    # Convert to lists with the same order
    ordered_labels = sorted(list(set(train_counts.keys()) | set(test_counts.keys())))
    ordered_names = [label_to_class.get(label, f"Class {label}") for label in ordered_labels]
    ordered_train = [train_counts[label] for label in ordered_labels]
    ordered_test = [test_counts[label] for label in ordered_labels]
    
    plt.bar(x - width/2, ordered_train, width, label='Training')
    plt.bar(x + width/2, ordered_test, width, label='Testing')
    
    plt.xlabel('Class')
    plt.ylabel('Number of Files')
    plt.title('Class Distribution - Training vs Testing')
    plt.xticks(x, ordered_names, rotation=90)
    plt.legend()
    plt.tight_layout()
    plt.show()

    return (
        np.array(train_data), np.array(train_labels), train_files,
        np.array(test_data), np.array(test_labels), test_files
    )

# Function to load additional training data for each group
def load_additional_train_data(data_dir, label_mapping, file_type, train_chirp_files, target_shape=(128, 128)):
    """
    Load additional training data for a specific file type.
    Only loads files that correspond to the chirp files already in the training set.
    
    Args:
        data_dir: Directory containing the spectrograms
        label_mapping: Dictionary mapping primary_label to numerical label
        file_type: Type of spectrogram file to load (e.g., "_denoised.npy")
        train_chirp_files: List of chirp files in the training set
        target_shape: Target shape for resized spectrograms
        
    Returns:
        additional_data, additional_labels
    """
    additional_data = []
    additional_labels = []
    
    # Create a set of base filenames from training chirp files for efficient lookup
    base_filenames = {}
    for path in train_chirp_files:
        folder_name = os.path.basename(os.path.dirname(path))  # Get folder name (class ID)
        base_filename = os.path.basename(path).replace('_chirp.npy', '')  # Get base filename
        base_filenames[(folder_name, base_filename)] = path
    
    # Count matches found
    match_count = 0
    
    # Now load the corresponding files with the specified file_type
    for folder_name in os.listdir(data_dir):
        if folder_name in label_mapping:
            label = label_mapping[folder_name]
            folder_path = os.path.join(data_dir, folder_name)
            
            for filename in os.listdir(folder_path):
                if file_type in filename:
                    base_filename = filename.replace(file_type, '')
                    
                    # Check if we have the corresponding chirp file in training set
                    if (folder_name, base_filename) in base_filenames:
                        file_path = os.path.join(folder_path, filename)
                        try:
                            spectrogram = np.load(file_path)
                            spectrogram = resize(spectrogram, target_shape, mode='reflect', anti_aliasing=True)
                            spectrogram = np.expand_dims(spectrogram, axis=-1)
                            additional_data.append(spectrogram)
                            additional_labels.append(label)
                            match_count += 1
                        except Exception as e:
                            print(f"Error loading {file_path}: {e}")
    
    print(f"Found {match_count} matching {file_type} files for training chirp files")
    
    return np.array(additional_data), np.array(additional_labels)

# Function to print group distribution
def print_group_distribution(X_train, y_train, label_to_class, group_name):
    """
    Print the distribution of classes in a training group
    
    Args:
        X_train: Training features
        y_train: Training labels
        label_to_class: Dictionary mapping numerical label to class name
        group_name: Name of the group
    """
    class_counts = defaultdict(int)
    for label in y_train:
        class_counts[label] += 1
    
    print(f"\n===== Class Distribution for {group_name} =====")
    print(f"{'Class Name':<30} | {'Count':<10} | {'Percentage':<10}")
    print("-" * 55)
    
    total = len(y_train)
    
    for label in sorted(class_counts.keys()):
        class_name = label_to_class.get(label, f"Class {label}")
        count = class_counts[label]
        percentage = (count / total) * 100
        
        print(f"{class_name[:30]:<30} | {count:<10} | {percentage:.2f}%")
    
    print("-" * 55)
    print(f"{'Total':<30} | {total:<10} | 100.00%")
    
    # Plot the distribution
    plt.figure(figsize=(12, 8))
    
    # Convert to lists with the same order for plotting
    ordered_labels = sorted(class_counts.keys())
    ordered_names = [label_to_class.get(label, f"Class {label}") for label in ordered_labels]
    ordered_counts = [class_counts[label] for label in ordered_labels]
    
    plt.bar(ordered_names, ordered_counts)
    plt.xlabel('Class')
    plt.ylabel('Number of Files')
    plt.title(f'Class Distribution - {group_name}')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# Function to evaluate model
def evaluate_model(model, history, X_test, y_test, le, group_name=None):
    """
    Evaluate the model and visualize results
    
    Args:
        model: Trained model
        history: Training history
        X_test: Test features
        y_test: Test labels (one-hot encoded)
        le: LabelEncoder used for class names
        group_name: Name of the group
        
    Returns:
        Dictionary with evaluation metrics
    """
    # 1. Plot train and validate accuracy / loss curve
    plt.figure(figsize=(12, 5))
    
    title_suffix = f" - {group_name}" if group_name else ""

    # Accuracy curve
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title(f'Training and Validation Accuracy{title_suffix}')

    # Loss curve
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title(f'Training and Validation Loss{title_suffix}')

    plt.tight_layout()
    plt.show()

    # 2. Model predict for report
    y_pred_probs = model.predict(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # 3. Output classification report
    print(f"\nClassification Report{title_suffix}:")
    print(classification_report(y_true, y_pred, target_names=le.classes_))

    # 4. Plot Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.classes_)
    plt.figure(figsize=(10, 8))
    disp.plot(cmap='Blues', values_format='d')
    plt.title(f"Confusion Matrix{title_suffix}")
    plt.show()

    # 5. ROC Curve (multi-classification one-vs-rest)
    plt.figure(figsize=(12, 8))

    for i, class_name in enumerate(le.classes_):
        fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_probs[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'{class_name} (AUC = {roc_auc:.2f})')

    plt.plot([0, 1], [0, 1], 'k--', label='Random')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Multi-class ROC Curve (One-vs-Rest){title_suffix}')
    plt.legend(loc='lower right', fontsize='small')
    plt.grid(True)
    plt.show()
    
    # Return metrics for comparison
    return {
        'y_pred': y_pred,
        'y_true': y_true,
        'y_pred_probs': y_pred_probs,
        'accuracy': history.history['val_accuracy'][-1]
    }

# Function to create model
def create_model(input_shape, num_classes):
    """
    Create and compile a CNN model
    
    Args:
        input_shape: Shape of input data
        num_classes: Number of output classes
        
    Returns:
        Compiled model
    """
    input_layer = Input(shape=input_shape)
    
    # Convolutional layers
    x = Conv2D(32, (3, 3), activation='relu')(input_layer)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    
    # Fully connected layers
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output_layer = Dense(num_classes, activation='softmax')(x)
    
    # Create and compile model
    model = Model(input_layer, output_layer)
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# Main function
def main():
    # Config
    data_dir = 'mel_spectrograms'
    csv_path = 'taxonomy.csv'
    target_shape = (128, 64)
    test_ratio = 0.2
    
    # Loading metadata
    metadata = pd.read_csv(csv_path)
    
    # Encode class_name to numerical label
    le = LabelEncoder()
    metadata['label'] = le.fit_transform(metadata['class_name'])
    
    # Map primary_label -> label
    label_mapping = dict(zip(metadata['primary_label'].astype(str), metadata['label']))
    
    # Map label -> class_name (for display)
    label_to_class = dict(zip(metadata['label'], metadata['class_name']))
    
    # Define the 4 groups
    groups = [
        {
            'name': 'Group 1: chirp + denoised',
            'file_types': ['_chirp.npy', '_denoised.npy']
        },
        {
            'name': 'Group 2: chirp + denoised_hpss',
            'file_types': ['_chirp.npy', '_denoised_hpss.npy']
        },
        {
            'name': 'Group 3: chirp + denoised_median_filter',
            'file_types': ['_chirp.npy', '_denoised_median_filter.npy']
        },
        {
            'name': 'Group 4: chirp + denoised_spectral',
            'file_types': ['_chirp.npy', '_denoised_spectral.npy']
        }
    ]
    
    # Lists to store results
    history_list = []
    model_list = []
    evaluation_results = []
    
    # Step 1: Explore data distribution
    print("\n" + "="*60)
    print("STEP 1: EXPLORING DATA DISTRIBUTION")
    print("="*60)
    chirp_df = explore_data_distribution(data_dir, label_mapping, metadata)
    
    print("\n" + "-"*60 + "\n")
    
    # Step 2: Get balanced train/test split for chirp files
    print("\n" + "="*60)
    print("STEP 2: CREATING BALANCED TRAIN/TEST SPLIT")
    print("="*60)
    X_train_chirp, y_train_chirp, train_files_chirp, X_test, y_test_raw, test_files = split_balanced_train_test(
        data_dir, label_mapping, metadata, target_shape=target_shape, test_ratio=test_ratio
    )
    
    # Convert test labels to categorical
    num_classes = len(np.unique(y_test_raw))
    y_test = to_categorical(y_test_raw, num_classes=num_classes)
    
    print(f"\nBase training set (chirp only): {len(X_train_chirp)} samples")
    print(f"Test set: {len(X_test)} samples")
    
    # Early stopping callback
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=5,
        min_delta=0.001,
        restore_best_weights=True,
        verbose=1
    )
    
    # Step 3: Train and evaluate models for each group
    print("\n" + "="*60)
    print("STEP 3: TRAINING AND EVALUATING MODELS")
    print("="*60)
    
    for group in groups:
        print(f"\n{'='*80}")
        print(f"Processing {group['name']}")
        print(f"{'='*80}")
        
        # Start with chirp files (already balanced)
        X_train_combined = X_train_chirp.copy()
        y_train_combined = y_train_chirp.copy()
        
        # Add the other file type from this group
        other_file_type = [ft for ft in group['file_types'] if ft != '_chirp.npy'][0]
        X_additional, y_additional = load_additional_train_data(
            data_dir, label_mapping, other_file_type, train_files_chirp, target_shape
        )
        
        # Combine datasets if we found additional files
        if len(X_additional) > 0:
            X_train_combined = np.concatenate([X_train_combined, X_additional])
            y_train_combined = np.concatenate([y_train_combined, y_additional])
        
        # Print distribution for this group
        print_group_distribution(X_train_combined, y_train_combined, label_to_class, group['name'])
        
        # Convert to categorical
        y_train = to_categorical(y_train_combined, num_classes=num_classes)
        
        # Create and compile model
        model = create_model(X_train_combined[0].shape, num_classes)
        print(model.summary())
        
        # Train the model with early stopping
        print(f"\nTraining with {len(X_train_combined)} samples, testing with {len(X_test)} samples")
        history = model.fit(
            X_train_combined, y_train,
            validation_data=(X_test, y_test),
            epochs=20,
            batch_size=32,
            verbose=1,
            callbacks=[early_stopping]
        )
        
        # Store model and history
        history_list.append(history)
        model_list.append(model)
        
        # Evaluate the model
        print(f"\nEvaluating {group['name']}...")
        eval_result = evaluate_model(model, history, X_test, y_test, le, group['name'])
        evaluation_results.append(eval_result)
    
    # Step 4: Final comparison of all models
    print("\n" + "="*60)
    print("STEP 4: MODEL PERFORMANCE COMPARISON")
    print("="*60)
    
    # Accuracy comparison table
    print("\nAccuracy Comparison:")
    print(f"{'Group':40} | {'Final Validation Accuracy':25}")
    print("-" * 70)
    for i, group in enumerate(groups):
        print(f"{group['name']:40} | {evaluation_results[i]['accuracy']:.6f}")
    
    # Plot accuracy comparison across all models
    plt.figure(figsize=(12, 6))
    
    # Training accuracy
    plt.subplot(1, 2, 1)
    for i, history in enumerate(history_list):
        plt.plot(history.history['accuracy'], label=f"Group {i+1}")
    plt.title('Training Accuracy Comparison')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)
    
    # Validation accuracy
    plt.subplot(1, 2, 2)
    for i, history in enumerate(history_list):
        plt.plot(history.history['val_accuracy'], label=f"Group {i+1}")
    plt.title('Validation Accuracy Comparison')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()
    
    # Print stopping epoch for each model
    print("\nTraining Duration:")
    print(f"{'Group':40} | {'Epochs Trained':15} | {'Early Stopped':15}")
    print("-" * 75)
    for i, history in enumerate(history_list):
        epochs_trained = len(history.history['loss'])
        early_stopped = epochs_trained < 20  # If we trained fewer than max epochs
        print(f"{groups[i]['name']:40} | {epochs_trained:15d} | {'Yes' if early_stopped else 'No':15}")
    
    # Class-wise accuracy comparison
    print("\nClass-wise Accuracy Comparison:")
    class_accuracies = {}
    
    # Calculate per-class accuracy for each model
    for i, result in enumerate(evaluation_results):
        y_true = result['y_true']
        y_pred = result['y_pred']
        
        for class_idx in range(num_classes):
            class_name = le.classes_[class_idx]
            if class_name not in class_accuracies:
                class_accuracies[class_name] = []
                
            # Get indices for this class
            class_indices = np.where(y_true == class_idx)[0]
            if len(class_indices) > 0:
                correct = np.sum(y_pred[class_indices] == class_idx)
                accuracy = correct / len(class_indices)
            else:
                accuracy = float('nan')
                
            class_accuracies[class_name].append(accuracy)
    
    # Print class-wise accuracies - fixing the syntax error in the original code
    print(f"{'Class':30} | " + " | ".join([f"Group {i+1}" for i in range(len(groups))]))
    print("-" * (30 + 13 * len(groups)))
    
    for class_name, accuracies in class_accuracies.items():
        acc_strings = [f"{acc:.4f}" if not np.isnan(acc) else "N/A" for acc in accuracies]
        print(f"{class_name:30} | " + " | ".join([f"{acc_str:10}" for acc_str in acc_strings]))
    
    # Find where models disagree
    print("\nAnalyzing samples where models disagree...")
    disagreements = []
    
    for i in range(len(X_test)):
        predictions = [evaluation_results[j]['y_pred'][i] for j in range(len(groups))]
        if len(set(predictions)) > 1:  # Models have different predictions
            disagreements.append({
                'index': i,
                'file': test_files[i],
                'true_class': le.classes_[evaluation_results[0]['y_true'][i]],
                'predictions': [le.classes_[pred] for pred in predictions]
            })
    
    print(f"\nFound {len(disagreements)} samples (out of {len(X_test)}) where models disagree")
    
    if disagreements:
        print("\nSample disagreements (first 5):")
        for i, d in enumerate(disagreements[:5]):
            print(f"Sample {i+1}: {os.path.basename(d['file'])}")
            print(f"  True class: {d['true_class']}")
            for j, group in enumerate(groups):
                print(f"  {group['name']}: predicted '{d['predictions'][j]}'")
            print()

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# STEP 1: EXPLORING DATA DISTRIBUTION
# ============================================================
#
# ===== Dataset Exploration =====
# Total number of .npy files: 5143
#
# File type distribution:
#   chirp: 1029 files
#   denoised: 1030 files
#   denoised_hpss: 1028 files
#   denoised_median_filter: 1028 files
#   denoised_spectral: 1028 files
#
# ===== Class Distribution (chirp files) =====
# Class Name                     | Count
# -------------------------------------------
# Amphibia                       | 583
# Mammalia                       | 178
# Insecta                        | 155
# Aves                           | 113
# ------------------------------------------------------------
#
#
# ============================================================
# STEP 2: CREATING BALANCED TRAIN/TEST SPLIT
# ============================================================
#
# ===== Class Distribution After Balanced Split =====
# Class Name                     | Training Count  | Test Count      | Total
# --------------------------------------------------------------------------------
# Amphibia                       | 90              | 23              | 113
# Aves                           | 90              | 23              | 113
# Insecta                        | 90              | 23              | 113
# Mammalia                       | 90              | 23              | 113
# --------------------------------------------------------------------------------
# Total                          | 360             | 92              | 452
# Base training set (chirp only): 360 samples
# Test set: 92 samples
#
# ============================================================
# STEP 3: TRAINING AND EVALUATING MODELS
# ============================================================
#
# ================================================================================
# Processing Group 1: chirp + denoised
# ================================================================================
# Found 360 matching _denoised.npy files for training chirp files
#
# ===== Class Distribution for Group 1: chirp + denoised =====
# Class Name                     | Count      | Percentage
# -------------------------------------------------------
# Amphibia                       | 180        | 25.00%
# Aves                           | 180        | 25.00%
# Insecta                        | 180        | 25.00%
# Mammalia                       | 180        | 25.00%
# -------------------------------------------------------
# Total                          | 720        | 100.00%
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 128, 64, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 126, 62, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 63, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 61, 29, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 30, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 28, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 14, 6, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 10752)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 128)            │     1,376,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,477,572 (5.64 MB)
#  Trainable params: 1,477,572 (5.64 MB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# Training with 720 samples, testing with 92 samples
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.2401 - loss: 1.3888 - val_accuracy: 0.4130 - val_loss: 1.3570
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.3725 - loss: 1.3121 - val_accuracy: 0.3804 - val_loss: 1.3415
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.4780 - loss: 1.2279 - val_accuracy: 0.4565 - val_loss: 1.1988
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.5568 - loss: 1.0580 - val_accuracy: 0.5326 - val_loss: 1.1197
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.6105 - loss: 0.9675 - val_accuracy: 0.5326 - val_loss: 1.0833
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.6459 - loss: 0.8557 - val_accuracy: 0.5870 - val_loss: 1.0668
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.6854 - loss: 0.7740 - val_accuracy: 0.6304 - val_loss: 0.9348
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7691 - loss: 0.6340 - val_accuracy: 0.6413 - val_loss: 0.9569
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.7940 - loss: 0.5603 - val_accuracy: 0.6630 - val_loss: 0.8868
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8422 - loss: 0.4883 - val_accuracy: 0.6848 - val_loss: 0.8402
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8321 - loss: 0.4380 - val_accuracy: 0.6957 - val_loss: 0.9239
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8876 - loss: 0.3651 - val_accuracy: 0.6848 - val_loss: 0.9427
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9340 - loss: 0.2249 - val_accuracy: 0.7174 - val_loss: 0.8966
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9252 - loss: 0.2098 - val_accuracy: 0.7174 - val_loss: 0.9731
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9459 - loss: 0.1674 - val_accuracy: 0.7174 - val_loss: 1.0324
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
#
# Evaluating Group 1: chirp + denoised...
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Classification Report - Group 1: chirp + denoised:
#               precision    recall  f1-score   support
#
#     Amphibia       0.74      0.61      0.67        23
#         Aves       0.58      0.78      0.67        23
#      Insecta       0.83      0.83      0.83        23
#     Mammalia       0.63      0.52      0.57        23
#
#     accuracy                           0.68        92
#    macro avg       0.69      0.68      0.68        92
# weighted avg       0.69      0.68      0.68        92
# ================================================================================
# Processing Group 2: chirp + denoised_hpss
# ================================================================================
# Found 359 matching _denoised_hpss.npy files for training chirp files
#
# ===== Class Distribution for Group 2: chirp + denoised_hpss =====
# Class Name                     | Count      | Percentage
# -------------------------------------------------------
# Amphibia                       | 180        | 25.03%
# Aves                           | 179        | 24.90%
# Insecta                        | 180        | 25.03%
# Mammalia                       | 180        | 25.03%
# -------------------------------------------------------
# Total                          | 719        | 100.00%
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 128, 64, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 126, 62, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 63, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 61, 29, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 30, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 28, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 14, 6, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 10752)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 128)            │     1,376,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,477,572 (5.64 MB)
#  Trainable params: 1,477,572 (5.64 MB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# Training with 719 samples, testing with 92 samples
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.3043 - loss: 1.3962 - val_accuracy: 0.4565 - val_loss: 1.3494
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.4233 - loss: 1.2915 - val_accuracy: 0.4674 - val_loss: 1.2876
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.4886 - loss: 1.1670 - val_accuracy: 0.5217 - val_loss: 1.1763
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.5770 - loss: 0.9830 - val_accuracy: 0.5000 - val_loss: 1.1229
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6595 - loss: 0.8633 - val_accuracy: 0.5978 - val_loss: 1.0206
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.7375 - loss: 0.7206 - val_accuracy: 0.6087 - val_loss: 1.0558
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.7622 - loss: 0.5694 - val_accuracy: 0.6848 - val_loss: 1.0370
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.7918 - loss: 0.5282 - val_accuracy: 0.6630 - val_loss: 1.0116
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8284 - loss: 0.4331 - val_accuracy: 0.5978 - val_loss: 1.3301
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8473 - loss: 0.4180 - val_accuracy: 0.6848 - val_loss: 1.1278
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.9056 - loss: 0.2785 - val_accuracy: 0.6848 - val_loss: 1.2090
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.9255 - loss: 0.2040 - val_accuracy: 0.6848 - val_loss: 1.2604
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.9578 - loss: 0.1449 - val_accuracy: 0.7065 - val_loss: 1.2445
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
#
# Evaluating Group 2: chirp + denoised_hpss...
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
#
# Classification Report - Group 2: chirp + denoised_hpss:
#               precision    recall  f1-score   support
#
#     Amphibia       0.82      0.61      0.70        23
#         Aves       0.63      0.52      0.57        23
#      Insecta       0.84      0.70      0.76        23
#     Mammalia       0.51      0.83      0.63        23
#
#     accuracy                           0.66        92
#    macro avg       0.70      0.66      0.67        92
# weighted avg       0.70      0.66      0.67        92
# ================================================================================
# Processing Group 3: chirp + denoised_median_filter
# ================================================================================
# Found 359 matching _denoised_median_filter.npy files for training chirp files
#
# ===== Class Distribution for Group 3: chirp + denoised_median_filter =====
# Class Name                     | Count      | Percentage
# -------------------------------------------------------
# Amphibia                       | 180        | 25.03%
# Aves                           | 179        | 24.90%
# Insecta                        | 180        | 25.03%
# Mammalia                       | 180        | 25.03%
# -------------------------------------------------------
# Total                          | 719        | 100.00%
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 128, 64, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 126, 62, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 63, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 61, 29, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 30, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 28, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 14, 6, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 10752)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 128)            │     1,376,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,477,572 (5.64 MB)
#  Trainable params: 1,477,572 (5.64 MB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# Training with 719 samples, testing with 92 samples
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.2269 - loss: 1.4058 - val_accuracy: 0.4130 - val_loss: 1.3701
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.4491 - loss: 1.3315 - val_accuracy: 0.3152 - val_loss: 1.2886
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.4472 - loss: 1.2341 - val_accuracy: 0.4674 - val_loss: 1.2255
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.5924 - loss: 1.0813 - val_accuracy: 0.5109 - val_loss: 1.1256
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 0.6142 - loss: 0.9478 - val_accuracy: 0.6196 - val_loss: 1.0447
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.6983 - loss: 0.7867 - val_accuracy: 0.6087 - val_loss: 1.0677
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.7500 - loss: 0.6547 - val_accuracy: 0.6413 - val_loss: 0.9896
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.7848 - loss: 0.5899 - val_accuracy: 0.6630 - val_loss: 0.9992
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.8589 - loss: 0.4064 - val_accuracy: 0.6739 - val_loss: 0.9375
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.8606 - loss: 0.3760 - val_accuracy: 0.6848 - val_loss: 1.0175
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.9368 - loss: 0.2280 - val_accuracy: 0.7065 - val_loss: 1.3317
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.9514 - loss: 0.1837 - val_accuracy: 0.7065 - val_loss: 1.3197
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9563 - loss: 0.1532 - val_accuracy: 0.6848 - val_loss: 1.2739
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.9521 - loss: 0.1509 - val_accuracy: 0.6739 - val_loss: 1.7288
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 9.
#
# Evaluating Group 3: chirp + denoised_median_filter...
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step
#
# Classification Report - Group 3: chirp + denoised_median_filter:
#               precision    recall  f1-score   support
#
#     Amphibia       0.64      0.78      0.71        23
#         Aves       0.71      0.52      0.60        23
#      Insecta       0.88      0.65      0.75        23
#     Mammalia       0.57      0.74      0.64        23
#
#     accuracy                           0.67        92
#    macro avg       0.70      0.67      0.67        92
# weighted avg       0.70      0.67      0.67        92
# ================================================================================
# Processing Group 4: chirp + denoised_spectral
# ================================================================================
# Found 359 matching _denoised_spectral.npy files for training chirp files
#
# ===== Class Distribution for Group 4: chirp + denoised_spectral =====
# Class Name                     | Count      | Percentage
# -------------------------------------------------------
# Amphibia                       | 180        | 25.03%
# Aves                           | 179        | 24.90%
# Insecta                        | 180        | 25.03%
# Mammalia                       | 180        | 25.03%
# -------------------------------------------------------
# Total                          | 719        | 100.00%
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 128, 64, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 126, 62, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 63, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 61, 29, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 30, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 28, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_23 (MaxPooling2D) │ (None, 14, 6, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 10752)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 128)            │     1,376,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,477,572 (5.64 MB)
#  Trainable params: 1,477,572 (5.64 MB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# Training with 719 samples, testing with 92 samples
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 0.2836 - loss: 1.3876 - val_accuracy: 0.3696 - val_loss: 1.3377
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.4642 - loss: 1.2838 - val_accuracy: 0.5326 - val_loss: 1.2345
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.5092 - loss: 1.1409 - val_accuracy: 0.4348 - val_loss: 1.1973
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.6122 - loss: 0.9953 - val_accuracy: 0.5870 - val_loss: 1.1085
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.6707 - loss: 0.8878 - val_accuracy: 0.5978 - val_loss: 1.0295
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.7231 - loss: 0.7487 - val_accuracy: 0.6630 - val_loss: 0.9536
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.7297 - loss: 0.6809 - val_accuracy: 0.6739 - val_loss: 0.9313
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.7932 - loss: 0.5355 - val_accuracy: 0.6087 - val_loss: 0.9668
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.7767 - loss: 0.5930 - val_accuracy: 0.6848 - val_loss: 1.0190
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.8424 - loss: 0.4311 - val_accuracy: 0.7065 - val_loss: 0.9717
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.8567 - loss: 0.3678 - val_accuracy: 0.6630 - val_loss: 1.0362
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.8943 - loss: 0.2795 - val_accuracy: 0.6739 - val_loss: 1.0177
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
#
# Evaluating Group 4: chirp + denoised_spectral...
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
#
# Classification Report - Group 4: chirp + denoised_spectral:
#               precision    recall  f1-score   support
#
#     Amphibia       0.86      0.52      0.65        23
#         Aves       0.63      0.52      0.57        23
#      Insecta       0.76      0.83      0.79        23
#     Mammalia       0.56      0.83      0.67        23
#
#     accuracy                           0.67        92
#    macro avg       0.70      0.67      0.67        92
# weighted avg       0.70      0.67      0.67        92
# ============================================================
# STEP 4: MODEL PERFORMANCE COMPARISON
# ============================================================
#
# Accuracy Comparison:
# Group                                    | Final Validation Accuracy
# ----------------------------------------------------------------------
# Group 1: chirp + denoised                | 0.717391
# Group 2: chirp + denoised_hpss           | 0.706522
# Group 3: chirp + denoised_median_filter  | 0.673913
# Group 4: chirp + denoised_spectral       | 0.673913
# Training Duration:
# Group                                    | Epochs Trained  | Early Stopped
# ---------------------------------------------------------------------------
# Group 1: chirp + denoised                |              15 | Yes
# Group 2: chirp + denoised_hpss           |              13 | Yes
# Group 3: chirp + denoised_median_filter  |              14 | Yes
# Group 4: chirp + denoised_spectral       |              12 | Yes
#
# Class-wise Accuracy Comparison:
# Class                          | Group 1 | Group 2 | Group 3 | Group 4
# ----------------------------------------------------------------------------------
# Amphibia                       | 0.6087     | 0.6087     | 0.7826     | 0.5217
# Aves                           | 0.7826     | 0.5217     | 0.5217     | 0.5217
# Insecta                        | 0.8261     | 0.6957     | 0.6522     | 0.8261
# Mammalia                       | 0.5217     | 0.8261     | 0.7391     | 0.8261
#
# Analyzing samples where models disagree...
#
# Found 40 samples (out of 92) where models disagree
#
# Sample disagreements (first 5):
# Sample 1: CSA35173_chirp.npy
#   True class: Insecta
#   Group 1: chirp + denoised: predicted 'Insecta'
#   Group 2: chirp + denoised_hpss: predicted 'Insecta'
#   Group 3: chirp + denoised_median_filter: predicted 'Amphibia'
#   Group 4: chirp + denoised_spectral: predicted 'Insecta'
#
# Sample 2: CSA35185_chirp.npy
#   True class: Insecta
#   Group 1: chirp + denoised: predicted 'Mammalia'
#   Group 2: chirp + denoised_hpss: predicted 'Mammalia'
#   Group 3: chirp + denoised_median_filter: predicted 'Insecta'
#   Group 4: chirp + denoised_spectral: predicted 'Mammalia'
#
# Sample 3: CSA34428_chirp.npy
#   True class: Insecta
#   Group 1: chirp + denoised: predicted 'Aves'
#   Group 2: chirp + denoised_hpss: predicted 'Aves'
#   Group 3: chirp + denoised_median_filter: predicted 'Amphibia'
#   Group 4: chirp + denoised_spectral: predicted 'Aves'
#
# Sample 4: CSA35188_chirp.npy
#   True class: Insecta
#   Group 1: chirp + denoised: predicted 'Insecta'
#   Group 2: chirp + denoised_hpss: predicted 'Mammalia'
#   Group 3: chirp + denoised_median_filter: predicted 'Mammalia'
#   Group 4: chirp + denoised_spectral: predicted 'Insecta'
#
# Sample 5: CSA18801_chirp.npy
#   True class: Insecta
#   Group 1: chirp + denoised: predicted 'Insecta'
#   Group 2: chirp + denoised_hpss: predicted 'Insecta'
#   Group 3: chirp + denoised_median_filter: predicted 'Amphibia'
#   Group 4: chirp + denoised_spectral: predicted 'Insecta'
